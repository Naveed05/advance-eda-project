# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
# Load the dataset
df = pd.read_csv(r"C:\Users\mirza\Desktop\datasets\movies_rating_dataset.csv")

# %%
df
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
df.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
df.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.isna().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
df.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
df.shape
# Out:
# (559, 6)

# %%
df.columns = ['Film', 'Genre', 'CriticRating', "AudienceRating", "BudgetMillions", "year"]

# %%
df
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
df.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
df.head(1)
# Out:
#                     Film   Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer   Comedy            87              81
#
#    BudgetMillions  year
# 0               8  2009

# %%
df['Film'] = df['Film'].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
df['Genre'] = df['Genre'].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   year            559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
df['year'] = df['year'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
# plt.jointplot(x='CriticRating', y='AudienceRating', data=df) 
#  plt will not work in Jupyter Notebook, use sns.jointplot instead

sns.jointplot(x='CriticRating', y='AudienceRating', data=df)
plt.show()
#  at 0 point we have one outlier

# %%
sns.jointplot(x='CriticRating', y='AudienceRating', data=df, kind='scatter')  #kernal density graph 
plt.show()

# %%
j = sns. jointplot(x = 'CriticRating', y = 'AudienceRating',data = df, kind='hex')
plt.show()

# %%
sns.jointplot( data = df, x = 'CriticRating', y = 'AudienceRating', kind='reg')
plt.show() # kind='reg' for regression line
# plt.figure(figsize=(8, 6))
# sns.regplot(data=df, x='CriticRating', y='AudienceRating', scatter_kws={'alpha':0.5})
# plt.title('Critic Rating vs Audience Rating (Regression)')
# plt.show()

# %%
sns.distplot(df.AudienceRating)
plt.show()

# %%
sns.distplot(df.AudienceRating, bins = 15)
plt.show()

# %%
plt.hist(df.AudienceRating, bins=15, color='red', edgecolor='white')
plt.show()

# %%
sns.set_style('white') #normal distribution & called as bell curve
plt.hist(df.AudienceRating, bins=20)
plt.show()

# %%
plt.hist(df.CriticRating, bins=20)
plt.show()

# %%
sns.distplot(df.CriticRating, bins = 15)
plt.show()

# %%
plt.hist(df.BudgetMillions, bins=15)
plt.show()

# %%
plt.hist(df[df.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
plt.hist(df[df.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
plt.hist(df[df.Genre == 'Action'].BudgetMillions)
plt.show()

# %%
plt.hist(df[df.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
plt.hist(df[df.Genre == 'Action'].BudgetMillions, bins = 20, color='red')
plt.hist(df[df.Genre == 'Thriller'].BudgetMillions, bins = 20, color='green')
plt.hist(df[df.Genre == 'Drama'].BudgetMillions, bins = 20, color = 'blue' )
plt.legend()
plt.show()

# %%
for gen in df.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
sns.lmplot(data=df, x='CriticRating', y='AudienceRating', fit_reg=False)
plt.show()

# %%
sns.lmplot(data=df, x='CriticRating', y='AudienceRating',fit_reg=False, hue = 'Genre')
plt.show()
