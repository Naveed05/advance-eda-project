# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\mirza\Desktop\datasets\heart.csv")

# %%
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.shape
# Out:
# (303, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['target'].nunique()
# Out:
# 2

# %%
df['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
plt.subplots(figsize=(8, 6))
sns.countplot(x="target", data=df)
plt.show()

# %%
df.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
f , ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x = 'sex', hue = 'target', data = df)
plt.show()

# %%
ax = sns.catplot(x="target", col="sex", data=df, kind="count", height= 5, aspect= 1, hue= 'target')
plt.show()

# %%
f , ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x = 'target', data = df, palette = 'Set3')
plt.show()

# %%
f , ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x = 'target', data = df, palette = 'Set3')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x='target', data=df, facecolor=(0, 0, 0, 0), linewidth= 5, edgecolor=sns.color_palette('dark', 3))
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", hue="fbs", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", hue="exang", data=df)
plt.show()

# %%
correlation = df.corr()

# %%
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
#  if the correlation is greater than 0.5 or less than -0.5, it indicates a strong relationship
#  if the correlation is between 0.3 and 0.5 or -0.3 and -0.5, it indicates a moderate relationship
#  if the correlation is less than 0.3 or greater than -0.3 #  it indicates a weak relationship
#  if the correlation is equal to 0, it indicates no relationship       
# if correlation is near to +1, it indicates a strong positive relationship
# if correlation is near to -1, it indicates a strong negative relationship
# if correlation is near to 0, it indicates no relationship

# %%
df['cp'].nunique()
# Out:
# 4

# %%
df['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x = 'cp', data = df, hue= 'cp'   )
plt.show()

# %%
df.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x='cp',hue='target', data=df)
plt.show()

# %%
# f, ax = plt.subplots(figsize=(8, 6))
ax = sns.catplot(x='cp', col='target', data=df, kind='count', aspect=1, height=8)
plt.show()

# %%
ax = sns.catplot(x="target", col="cp", data=df, kind="count", height=5, aspect=1, hue='target')
plt.show()

# %%
df['thalach'].nunique()
# Out:
# 91

# %%
f, ax = plt.subplots(figsize=(8,7))
x= df['thalach']
ax = sns.distplot(x, bins= 10, color='red')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,7))
x= df['thalach']
ax = sns.distplot(x, bins= 10, color='red', kde=False   )
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = df['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.distplot(x, bins=10)
plt.show()

# %%
f, ax= plt.subplots(figsize=(10,6))
x= df['thalach']
x = pd.Series(x, name="thalach variable")
ax= sns.distplot(x, bins= 10 , color= 'blue')
ax.grid(True)
# The grid lines are not appearing because you assigned True to ax.grid instead of calling the grid() method.
# To show grid lines, use:
# ax.grid(True)
plt.show()

# %%
f, ax= plt.subplots(figsize=(10,6))
x= df['thalach']
x = pd.Series(x, name="thalach variable")
ax= sns.distplot(x, bins= 10 , color= 'blue', vertical=True)
# ax.grid(True)
# The grid lines are not appearing because you assigned True to ax.grid instead of calling the grid() method.
# To show grid lines, use:
# ax.grid(True)
plt.show()

# %%
f, ax= plt.subplots(figsize=(10,6))
x= df['thalach']
x = pd.Series(x, name="thalach variable")
ax= sns.distplot(x, bins= 10 , color= 'blue', vertical=False)
ax.grid(True)
# The grid lines are not appearing because you assigned True to ax.grid instead of calling the grid() method.
# To show grid lines, use:
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
x = df['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x, color='blue', vertical=False)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6) )
x = df['thalach']
# x = pd.series(x, name= 'thalach variable')
ax =sns.kdeplot(x, color='red', shade= True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = df['thalach']
ax = sns.distplot(x, bins = 10, kde=False, color='blue')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = df['thalach']
ax = sns.distplot(x, bins = 10, color='blue')
plt.show()
# we can see that the distribution of the 'thalach' variable is not normal, as it is skewed to the right side slightly.

# %%
f, ax = plt.subplots(figsize=(8,6))
x = df['thalach']
ax = sns.distplot(x, bins = 10, color='blue', kde =False, rug=True, hist_kws= {'edgecolor': 'black'})
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="target", y="thalach", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="target", y="thalach", data=df, jitter=False)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="target", y="thalach", data=df, hue='target', palette='Set2')
plt.show()

# we can see in this boxplot that the median of the 'thalach' variable is higher for the 'target' value of 0 compared to the 'target' value of 1.
# and there are some outliers in the 'thalach' variable for both 'target' values.
#  and that outliers are not affecting the median of the 'thalach' variable for both 'target' values.
# both the outliers are on the side of the 'target' value of 1, which indicates that the 'thalach' variable is higher for the 'target' value of 0 compared to the 'target' value of 1.

# %%
f, ax = plt.subplots(figsize = (8,6))
ax = sns.scatterplot(x = 'age', y = 'trestbps', data = df)
plt.show()
# for the scatter plot, we can see that there is no clear relationship between the 'age' and 'trestbps' variables.

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax= sns.regplot(x= 'age', y='trestbps', data=df)
plt.show()
# in this regression plot, we can see that there is no clear relationship between the 'age' and 'trestbps' variables.

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.scatterplot(x='age', y = 'chol', data = df)
plt.show()

# in this scatter plot, we can see that there is no clear relationship between the 'age' and 'chol' variables.

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.regplot(x='age', y = 'chol', data = df)
plt.show()
# in this regression plot, we can see that there is no clear relationship between the 'age' and 'chol' variables.

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.scatterplot(x='chol', y = 'thalach', data = df)
plt.show()
#  in this scatter plot, we can see that there is no clear relationship between the 'chol' and 'thalach' variables.

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x='chol', y = 'thalach', data=df)
plt.show()
# in this regression plot, we can see that there is no clear relationship between the 'chol' and 'thalach' variables.

# %%
df.isnull().sum()

# we can see that there are no missing values in the dataset.
# so there is no need to handle missing values in the dataset.
# we can proceed with the analysis without handling missing values.
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
assert pd.notnull(df).all().all()

# assert pd.notnull(df).all().all()  # This line checks if there are any missing values in the DataFrame.
# If there are no missing values, the assertion will pass silently. 
# If there are missing values, it will raise an AssertionError.
# This is a good way to ensure that your DataFrame is clean before proceeding with further analysis

# %%
# assert is passing silently, which means there are no missing values in the DataFrame.

# %%
assert (df >= 0).all().all()

# this line checks if all values in the DataFrame are greater than or equal to 0.
# If all values are greater than or equal to 0, the assertion will pass silently.
# and this is a good way to ensure that your DataFrame is clean before proceeding with further analysis.

# %%
df['age'].describe()

# The 'age' variable has a minimum value of 29 and a maximum value of 77, with a mean of 54.4 and a standard deviation of 9.08.
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=df["age"])
plt.show()

# box plot shows the distribution of the 'age' variable.
# it shows the minimum, maximum, median, and quartiles of the 'age' variable.
# there are no outliers in the 'age' variable.

# %%
df['trestbps'].describe()
# the trestbps variable has a minimum value of 94 and a maximum value of 200, with a mean of 131.6 and a standard deviation of 17.5.
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.boxplot(x=df["trestbps"])
plt.show()

# box plot shows the distribution of the 'trestbps' variable.
# it shows the minimum, maximum, median, and quartiles of the 'trestbps' variable.
# but on the right side of the box plot, we can see that there are some outliers in the 'trestbps' variable.
# these outliers are not affecting the median of the 'trestbps' variable.
# so they will not affect the analysis of the 'trestbps' variable.
# both the outliers are on the side of the 'target' value of 1,
# which indicates that the 'trestbps' variable is higher for the 'target' value of 1 compared to the 'target' value of 0.
# so will not consider this outliers as they are not affecting the analysis of the 'trestbps' variable.
# and we can proceed with the analysis without handling these outliers.

# %%
df['chol'].describe()
# the 'chol' variable has a minimum value of 126 and a maximum value of 564, with a mean of 246.3 and a standard deviation of 51.8.
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.boxplot(x=df["chol"])
plt.show()  

# box plot shows the distribution of the 'chol' variable.
# it shows the minimum, maximum, median, and quartiles of the 'chol' variable
# but on the right side of the box plot, we can see that there are some outliers in the 'chol' variable.
# these outliers are not affecting the median of the 'chol' variable.
# so they will not affect the analysis of the 'chol' variable.
# and we can proceed with the analysis without handling these outliers.

# %%
df['thalach'].describe()
# the 'thalach' variable has a minimum value of 71 and a maximum value of 202, with a mean of 149.6 and a standard deviation of 22.9.
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.boxplot(x=df["thalach"])
plt.show()

# box plot shows the distribution of the 'thalach' variable.
# it shows the minimum, maximum, median, and quartiles of the 'thalach'
# variable.# there are no outliers in the 'thalach' variable.
# so we can proceed with the analysis without handling outliers in the 'thalach' variable.
# we on the left side of the box plot we can see that one outlier is present, but it is not affecting the median of the 'thalach' variable.
# that outlirer is out of the range of the 'thalach' variable, but it is not affecting the median of the 'thalach' variable.

# %%
df['oldpeak'].describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=df["oldpeak"])
plt.show()

# box plot shows the distribution of the 'oldpeak' variable.
# it shows the minimum, maximum, median, and quartiles of the 'oldpeak'
# variable.
# there are no outliers in the 'oldpeak' variable.
# but on the right side of the box plot, we can see that there are some outliers in the 'oldpeak' variable.
# these outliers are not affecting the median of the 'oldpeak' variable.
# so they will not affect the analysis of the 'oldpeak' variable.
# and we can proceed with the analysis without handling these outliers.
